# %%
from ultralytics import YOLO

# %%
model=YOLO('models/yolo11n.pt')

# %%
pip install lap
# Out:
# Collecting lap
#   Downloading lap-0.5.12-cp39-cp39-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\goodm\appdata\local\programs\python\python39\lib\site-packages (from lap) (1.26.4)
# Downloading lap-0.5.12-cp39-cp39-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\goodm\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\goodm\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\goodm\appdata\local\programs\python\python39\lib\site-packages)

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("models/yolo11n.pt")

# Open the video file
video_path = "segment_24.mp4"
cap = cv2.VideoCapture(video_path)


# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 cars, 1 potted plant, 80.8ms
# Speed: 2.0ms preprocess, 80.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 82.7ms
# Speed: 1.4ms preprocess, 82.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 78.4ms
# Speed: 1.0ms preprocess, 78.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 84.9ms
# Speed: 1.2ms preprocess, 84.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 85.2ms
# Speed: 1.5ms preprocess, 85.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 88.4ms
# Speed: 1.0ms preprocess, 88.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 91.9ms
# Speed: 1.5ms preprocess, 91.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 88.7ms
# Speed: 1.7ms preprocess, 88.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 105.3ms
# Speed: 1.3ms preprocess, 105.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 73.4ms
# Speed: 1.5ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 71.9ms
# Speed: 1.0ms preprocess, 71.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 72.7ms
# Speed: 1.2ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 potted plant, 71.0ms
# Speed: 1.6ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 potted plant, 65.4ms
# Speed: 1.1ms preprocess, 65.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 70.7ms
# Speed: 1.1ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 potted plant, 71.9ms
# Speed: 1.1ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 67.4ms
# Speed: 1.1ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 71.8ms
# Speed: 1.2ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 91.6ms
# Speed: 2.0ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 85.1ms
# Speed: 1.3ms preprocess, 85.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 122.3ms
# Speed: 1.0ms preprocess, 122.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 78.5ms
# Speed: 1.1ms preprocess, 78.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 75.0ms
# Speed: 1.2ms preprocess, 75.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 88.1ms
# Speed: 1.3ms preprocess, 88.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 81.3ms
# Speed: 1.3ms preprocess, 81.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 80.6ms
# Speed: 1.4ms preprocess, 80.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 91.5ms
# Speed: 1.3ms preprocess, 91.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 93.5ms
# Speed: 1.4ms preprocess, 93.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 97.7ms
# Speed: 1.2ms preprocess, 97.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 83.4ms
# Speed: 2.5ms preprocess, 83.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 78.4ms
# Speed: 1.2ms preprocess, 78.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 75.8ms
# Speed: 1.3ms preprocess, 75.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 83.6ms
# Speed: 1.5ms preprocess, 83.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 77.3ms
# Speed: 1.2ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 74.2ms
# Speed: 1.2ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 81.7ms
# Speed: 1.2ms preprocess, 81.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 138.4ms
# Speed: 1.1ms preprocess, 138.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1
5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 138.2ms
# Speed: 1.9ms preprocess, 138.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 149.2ms
# Speed: 2.5ms preprocess, 149.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 117.2ms
# Speed: 2.2ms preprocess, 117.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 76.1ms
# Speed: 2.0ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 71.7ms
# Speed: 1.0ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 88.8ms
# Speed: 1.3ms preprocess, 88.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 90.5ms
# Speed: 1.3ms preprocess, 90.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 100.5ms
# Speed: 1.4ms preprocess, 100.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 91.4ms
# Speed: 1.7ms preprocess, 91.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 98.7ms
# Speed: 1.7ms preprocess, 98.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 92.4ms
# Speed: 1.3ms preprocess, 92.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 94.2ms
# Speed: 1.7ms preprocess, 94.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 potted plant, 108.2ms
# Speed: 1.8ms preprocess, 108.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 potted plant, 97.7ms
# Speed: 1.4ms preprocess, 97.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 2 cars, 1 potted plant, 99.7ms
# Speed: 2.1ms preprocess, 99.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 2 cars, 1 potted plant, 98.8ms
# Speed: 1.6ms preprocess, 98.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 2 cars, 1 potted plant, 109.3ms
# Speed: 1.6ms preprocess, 109.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 potted plant, 105.7ms
# Speed: 1.7ms preprocess, 105.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 101.1ms
# Speed: 1.6ms preprocess, 101.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 94.1ms
# Speed: 2.2ms preprocess, 94.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 95.3ms
# Speed: 2.1ms preprocess, 95.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 93.1ms
# Speed: 1.6ms preprocess, 93.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 94.0ms
# Speed: 1.7ms preprocess, 94.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 90.4ms
# Speed: 1.9ms preprocess, 90.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 95.9ms
# Speed: 1.5ms preprocess, 95.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 92.7ms
# Speed: 1.5ms preprocess, 92.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 100.5ms
# Speed: 1.4ms preprocess, 100.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 91.4ms
# Speed: 1.5ms preprocess, 91.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 109.4ms
# Speed: 1.6ms preprocess, 109.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 97.3ms
# Speed: 1.8ms preprocess, 97.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 98.9ms
# Speed: 1.5ms preprocess, 98.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 97.2ms
# Speed: 1.4ms preprocess, 97.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 107.2ms
# Speed: 1.7ms preprocess, 107.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 95.3ms
# Speed: 1.8ms preprocess, 95.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 106.6ms
# Speed: 1.4ms preprocess, 106.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 fire hydrant, 1 potted plant, 103.6ms
# Speed: 1.9ms preprocess, 103.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 112.1ms
# Speed: 1.5ms preprocess, 112.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 109.1ms
# Speed: 1.6ms preprocess, 109.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 fire hydrant, 1 potted plant, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1
2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 96.6ms
# Speed: 1.8ms preprocess, 96.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 100.9ms
# Speed: 1.6ms preprocess, 100.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 94.2ms
# Speed: 1.9ms preprocess, 94.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 92.4ms
# Speed: 1.5ms preprocess, 92.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 94.3ms
# Speed: 1.5ms preprocess, 94.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 118.2ms
# Speed: 1.6ms preprocess, 118.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 89.4ms
# Speed: 1.4ms preprocess, 89.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 100.9ms
# Speed: 1.5ms preprocess, 100.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 114.0ms
# Speed: 1.4ms preprocess, 114.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 100.5ms
# Speed: 1.4ms preprocess, 100.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 99.9ms
# Speed: 1.5ms preprocess, 99.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 101.6ms
# Speed: 1.8ms preprocess, 101.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 108.9ms
# Speed: 1.5ms preprocess, 108.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 96.6ms
# Speed: 1.6ms preprocess, 96.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 97.7ms
# Speed: 1.8ms preprocess, 97.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 104.5ms
# Speed: 1.9ms preprocess, 104.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 105.7ms
# Speed: 1.5ms preprocess, 105.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 traffic light, 1 potted plant, 93.0ms
# Speed: 1.6ms preprocess, 93.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 4 cars, 1 traffic light, 1 potted plant, 99.3ms
# Speed: 1.5ms preprocess, 99.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 5 cars, 1 traffic light, 1 potted plant, 96.4ms
# Speed: 1.4ms preprocess, 96.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 cars, 1 traffic light, 1 potted plant, 97.1ms
# Speed: 1.6ms preprocess, 97.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 cars, 1 traffic light, 1 potted plant, 100.4ms
# Speed: 1.5ms preprocess, 100.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 5 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 115.6ms
# Speed: 1.8ms preprocess, 115.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 114.2ms
# Speed: 1.5ms preprocess, 114.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 135.3ms
# Speed: 2.1ms preprocess, 135.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 107.2ms
# Speed: 1.9ms preprocess, 107.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 105.0ms
# Speed: 1.5ms preprocess, 105.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 110.7ms
# Speed: 1.8ms preprocess, 110.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 107.0ms
# Speed: 1.8ms preprocess, 107.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 100.4ms
# Speed: 2.1ms preprocess, 100.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 90.1ms
# Speed: 1.6ms preprocess, 90.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 91.6ms
# Speed: 1.4ms preprocess, 91.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 94.0ms
# Speed: 1.4ms preprocess, 94.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 96.8ms
# Speed: 1.5ms preprocess, 96.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 90.7ms
# Speed: 1.5ms preprocess, 90.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 94.4ms
# Speed: 1.5ms preprocess, 94.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 94.2ms
# Speed: 1.5ms preprocess, 94.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 96.3ms
# Speed: 1.4ms preprocess, 96.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 88.6ms
# Speed: 1.8ms preprocess, 88.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 95.4ms
# Speed: 1.4ms preprocess, 95.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 99.8ms
# Speed: 3.0ms preprocess, 99.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 113.2ms
# Speed: 1.7ms preprocess, 113.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 traffic light, 1 potted plant, 95.8ms
# Speed: 1.5ms preprocess, 95.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 cars, 1 traffic light, 1 potted plant, 115.5ms
# Speed: 1.3ms preprocess, 115.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 98.8ms
# Speed: 1.8ms preprocess, 98.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 95.2ms
# Speed: 1.4ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 98.9ms
# Speed: 1.5ms preprocess, 98.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 94.3ms
# Speed: 1.9ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 94.7ms
# Speed: 1.9ms preprocess, 94.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 4 cars, 1 traffic light, 1 potted plant, 93.3ms
# Speed: 1.5ms preprocess, 93.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 98.5ms
# Speed: 1.5ms preprocess, 98.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 99.9ms
# Speed: 1.5ms preprocess, 99.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 91.9ms
# Speed: 1.4ms preprocess, 91.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 124.5ms
# Speed: 1.7ms preprocess, 124.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 127.3ms
# Speed: 1.9ms preprocess, 127.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 92.3ms
# Speed: 1.5ms preprocess, 92.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 101.1ms
# Speed: 1.6ms preprocess, 101.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 111.9ms
# Speed: 2.0ms preprocess, 111.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 116.5ms
# Speed: 1.7ms preprocess, 116.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 123.6ms
# Speed: 1.8ms preprocess, 123.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 116.7ms
# Speed: 1.8ms preprocess, 116.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 98.4ms
# Speed: 1.7ms preprocess, 98.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 98.1ms
# Speed: 1.7ms preprocess, 98.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 94.8ms
# Speed: 1.6ms preprocess, 94.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 87.4ms
# Speed: 1.9ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 102.2ms
# Speed: 1.8ms preprocess, 102.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 89.1ms
# Speed: 1.5ms preprocess, 89.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 94.4ms
# Speed: 1.5ms preprocess, 94.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 97.5ms
# Speed: 1.6ms preprocess, 97.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 102.1ms
# Speed: 1.3ms preprocess, 102.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 91.9ms
# Speed: 1.4ms preprocess, 91.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 111.0ms
# Speed: 1.5ms preprocess, 111.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 90.1ms
# Speed: 1.8ms preprocess, 90.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 109.7ms
# Speed: 2.1ms preprocess, 109.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 97.3ms
# Speed: 1.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 97.6ms
# Speed: 1.9ms preprocess, 97.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 95.6ms
# Speed: 1.6ms preprocess, 95.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 94.1ms
# Speed: 1.5ms preprocess, 94.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 95.9ms
# Speed: 1.4ms preprocess, 95.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 90.8ms
# Speed: 1.4ms preprocess, 90.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 100.3ms
# Speed: 1.4ms preprocess, 100.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 89.7ms
# Speed: 1.6ms preprocess, 89.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 96.7ms
# Speed: 1.5ms preprocess, 96.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 91.3ms
# Speed: 1.5ms preprocess, 91.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 90.4ms
# Speed: 1.7ms preprocess, 90.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 96.0ms
# Speed: 1.4ms preprocess, 96.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 99.6ms
# Speed: 1.3ms preprocess, 99.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 101.7ms
# Speed: 1.5ms preprocess, 101.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 96.3ms
# Speed: 1.9ms preprocess, 96.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 109.1ms
# Speed: 1.8ms preprocess, 109.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 113.0ms
# Speed: 1.8ms preprocess, 113.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 3 cars, 1 traffic light, 1 potted plant, 97.5ms
# Speed: 1.5ms preprocess, 97.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 94.3ms
# Speed: 1.5ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 traffic light, 1 potted plant, 102.3ms
# Speed: 1.5ms preprocess, 102.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 truck, 1 traffic light, 1 potted plant, 97.0ms
# Speed: 1.4ms preprocess, 97.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bicycle, 2 cars, 1 traffic light, 1 potted plant, 97.5ms
# Speed: 1.5ms preprocess, 97.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bicycle, 1 car, 1 truck, 1 traffic light, 1 potted plant, 96.3ms
# Speed: 1.6ms preprocess, 96.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 traffic light, 1 potted plant, 96.6ms
# Speed: 1.3ms preprocess, 96.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 traffic light, 1 potted plant, 92.5ms
# Speed: 1.4ms preprocess, 92.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 cars, 1 traffic light, 1 potted plant, 90.7ms
# Speed: 1.4ms preprocess, 90.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 traffic light, 1 potted plant, 90.9ms
# Speed: 1.5ms preprocess, 90.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 traffic light, 1 potted plant, 106.4ms
# Speed: 1.5ms preprocess, 106.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 cars, 1 traffic light, 1 potted plant, 100.3ms
# Speed: 1.9ms preprocess, 100.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 traffic light, 1 potted plant, 113.3ms
# Speed: 1.7ms preprocess, 113.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 traffic light, 1 potted plant, 97.1ms
# Speed: 1.9ms preprocess, 97.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 traffic light, 1 potted plant, 97.1ms
# Speed: 1.5ms preprocess, 97.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 traffic light, 1 potted plant, 99.8ms
# Speed: 1.7ms preprocess, 99.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 traffic light, 1 potted plant, 93.1ms
# Speed: 1.5ms preprocess, 93.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 boat, 1 traffic light, 1 potted plant, 95.1ms
# Speed: 1.6ms preprocess, 95.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cars, 1 traffic light, 1 potted plant, 91.8ms
# ...
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 101.5ms
# Speed: 1.8ms preprocess, 101.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 107.7ms
# Speed: 1.4ms preprocess, 107.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 106.2ms
# Speed: 1.9ms preprocess, 106.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 125.5ms
# Speed: 1.5ms preprocess, 125.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 130.4ms
# Speed: 2.0ms preprocess, 130.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 112.9ms
# Speed: 2.0ms preprocess, 112.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 102.7ms
# Speed: 1.5ms preprocess, 102.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 94.8ms
# Speed: 1.5ms preprocess, 94.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 131.3ms
# Speed: 1.9ms preprocess, 131.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 traffic light, 1 potted plant, 119.5ms
# Speed: 1.7ms preprocess, 119.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 traffic light, 1 potted plant, 116.3ms
# Speed: 1.9ms preprocess, 116.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 traffic light, 1 potted plant, 116.4ms
# Speed: 2.0ms preprocess, 116.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 traffic light, 1 potted plant, 110.1ms
# Speed: 1.8ms preprocess, 110.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 traffic light, 1 potted plant, 122.5ms
# Speed: 2.0ms preprocess, 122.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 traffic light, 1 potted plant, 132.7ms
# Speed: 2.0ms preprocess, 132.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 traffic light, 1 potted plant, 132.9ms
# Speed: 2.1ms preprocess, 132.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 traffic light, 1 potted plant, 127.0ms
# Speed: 2.2ms preprocess, 127.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 traffic light, 1 potted plant, 109.5ms
# Speed: 2.1ms preprocess, 109.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1
8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 116.8ms
# Speed: 1.8ms preprocess, 116.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 101.7ms
# Speed: 1.9ms preprocess, 101.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 101.8ms
# Speed: 1.8ms preprocess, 101.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 95.9ms
# Speed: 1.6ms preprocess, 95.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 potted plant, 98.9ms
# Speed: 1.5ms preprocess, 98.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 traffic light, 1 potted plant, 107.3ms
# Speed: 1.4ms preprocess, 107.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 potted plant, 121.6ms
# Speed: 1.9ms preprocess, 121.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 potted plant, 104.8ms
# Speed: 1.8ms preprocess, 104.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 potted plant, 98.8ms
# Speed: 1.6ms preprocess, 98.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 potted plant, 98.9ms
# Speed: 1.5ms preprocess, 98.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 fire hydrant, 1 potted plant, 97.3ms
# Speed: 1.7ms preprocess, 97.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 99.2ms
# Speed: 1.6ms preprocess, 99.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 92.0ms
# Speed: 1.8ms preprocess, 92.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 95.4ms
# Speed: 1.6ms preprocess, 95.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 95.2ms
# Speed: 1.7ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 110.7ms
# Speed: 1.6ms preprocess, 110.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 114.7ms
# Speed: 1.5ms preprocess, 114.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 101.0ms
# Speed: 1.6ms preprocess, 101.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 99.9ms
# Speed: 1.6ms preprocess, 99.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 98.9ms
# Speed: 1.8ms preprocess, 98.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 105.5ms
# Speed: 1.5ms preprocess, 105.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 119.7ms
# Speed: 1.6ms preprocess, 119.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 potted plant, 129.3ms
# Speed: 1.5ms preprocess, 129.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 potted plant, 100.2ms
# Speed: 1.7ms preprocess, 100.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 potted plant, 101.9ms
# Speed: 1.5ms preprocess, 101.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 1 potted plant, 102.0ms
# Speed: 1.8ms preprocess, 102.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)

# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO

# Load the YOLO model (ensure this is the correct model)
model = YOLO("models/yolo11n.pt")  # Use "yolov8n.pt" instead of "yolo11n.pt" (no "yolo11" exists)

# Open the video file
video_path = "segment_24.mp4"
cap = cv2.VideoCapture(video_path)

# Store tracking history and unique object IDs
track_history = defaultdict(lambda: [])
unique_objects = set()

# Define class IDs for cars, bicycles, and people (COCO dataset)
CLASSES_TO_DETECT = {
    0: "person",
    1: "bicycle",
    2: "car"
}

# Store object counts
object_counts = {cls: 0 for cls in CLASSES_TO_DETECT}

# Loop through video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO object tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Get the boxes, class IDs, and track IDs
        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xywh.cpu()  # Get bounding boxes
            track_ids = results[0].boxes.id.int().cpu().tolist()  # Get track IDs
            class_ids = results[0].boxes.cls.int().cpu().tolist()  # Get class IDs

            # Visualize the results on the frame
            annotated_frame = results[0].plot()

            # Track and count unique objects
            for box, track_id, cls in zip(boxes, track_ids, class_ids):
                if cls in CLASSES_TO_DETECT:
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))  # Store track points
                    if len(track) > 30:  # Keep the last 30 frames of history
                        track.pop(0)

                    # Ensure unique objects are only counted once
                    if track_id not in unique_objects:
                        unique_objects.add(track_id)
                        object_counts[cls] += 1  # Increment count for class

                    # Draw tracking lines
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=3)

            # Overlay the tally on the video
            tally_text = f"Cars: {object_counts[2]} | Bicycles: {object_counts[1]} | People: {object_counts[0]}"
            cv2.putText(annotated_frame, tally_text, (20, 50),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

            # Display the annotated frame
            cv2.imshow("YOLO Object Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Print final count in the log
print(f"\nFinal Tally:")
print(f"Cars: {object_counts[2]}")
print(f"Bicycles: {object_counts[1]}")
print(f"People: {object_counts[0]}")

# Release video capture and close display
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 cars, 1 potted plant, 74.8ms
# Speed: 2.2ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 98.7ms
# Speed: 1.3ms preprocess, 98.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 95.6ms
# Speed: 1.3ms preprocess, 95.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 81.8ms
# Speed: 1.4ms preprocess, 81.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 82.2ms
# Speed: 1.3ms preprocess, 82.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 84.2ms
# Speed: 1.3ms preprocess, 84.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 94.0ms
# Speed: 1.3ms preprocess, 94.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 80.3ms
# Speed: 1.2ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 84.0ms
# Speed: 1.3ms preprocess, 84.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 76.4ms
# Speed: 1.1ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 73.8ms
# Speed: 1.1ms preprocess, 73.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 67.5ms
# Speed: 1.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 potted plant, 64.6ms
# Speed: 1.0ms preprocess, 64.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 potted plant, 71.2ms
# Speed: 1.0ms preprocess, 71.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 66.6ms
# Speed: 1.1ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 potted plant, 64.7ms
# Speed: 1.1ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 71.9ms
# Speed: 1.2ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 66.2ms
# Speed: 1.1ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 67.0ms
# Speed: 1.1ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 68.8ms
# Speed: 1.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 64.6ms
# Speed: 1.3ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 138.5ms
# Speed: 5.7ms preprocess, 138.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 105.6ms
# Speed: 1.5ms preprocess, 105.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 101.5ms
# Speed: 1.8ms preprocess, 101.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 85.8ms
# Speed: 1.5ms preprocess, 85.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 77.9ms
# Speed: 1.3ms preprocess, 77.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 80.0ms
# Speed: 1.2ms preprocess, 80.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 80.6ms
# Speed: 1.3ms preprocess, 80.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 79.5ms
# Speed: 1.3ms preprocess, 79.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 79.7ms
# Speed: 1.4ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 67.5ms
# Speed: 1.1ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 70.4ms
# Speed: 1.0ms preprocess, 70.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 66.1ms
# Speed: 1.0ms preprocess, 66.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 1 potted plant, 68.0ms
# Speed: 1.1ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 67.5ms
# Speed: 1.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Final Tally:
# Cars: 5
# Bicycles: 0
# People: 2

# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLO model and move to GPU
model = YOLO("models/yolo11m.pt")

# Open the video file
video_path = "segment_24.mp4"
cap = cv2.VideoCapture(video_path)

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

#playback speed
PLAYBACK_SPEED = 5
frame_rate=fps*PLAYBACK_SPEED

# Video writer to save the processed output
output_path = "processed_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps // 3, (width, height))  # Process 1/3 of frames

# Store tracking history and unique object IDs
track_history = defaultdict(lambda: [])
unique_objects = set()

# Define class IDs for cars, bicycles, and people (COCO dataset)
CLASSES_TO_DETECT = {
    0: "person",
    1: "bicycle",
    2: "car",
    3: "motorcycle",
    5: "bus",
    7: "truck"
}

# Store object counts
object_counts = {cls: 0 for cls in CLASSES_TO_DETECT}

# Confidence threshold for counting
CONFIDENCE_THRESHOLD = 0.6  # Objects must have at least 75% confidence
FRAME_THRESHOLD_Y = height // 3  # Only count objects in the lower 2/3 of the frame
FRAME_SKIP = 5  # Process every 3rd frame for efficiency

# Initialize contrast enhancement
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))  # Adaptive histogram equalization

# Loop through video frames
frame_number = 0
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    # **Play video at 2x or 3x speed**
    if frame_number % PLAYBACK_SPEED != 0:
        frame_number += 1
        continue

    # **Skip frames dynamically for speed-up**
    if frame_number % FRAME_SKIP != 0:
        frame_number += 1
        continue

    # Adaptive brightness correction
    lab = cv2.cvtColor(frame, cv2.COLOR_BGR2LAB)  # Convert to LAB color space
    l, a, b = cv2.split(lab)  # Split channels
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))  # Apply CLAHE
    l = clahe.apply(l)
    enhanced_lab = cv2.merge((l, a, b))  # Merge channels back
    frame = cv2.cvtColor(enhanced_lab, cv2.COLOR_LAB2BGR)  # Convert back to BGR

    # Run YOLO object tracking on the frame
    results = model.track(frame, persist=True)

    # Get the boxes, class IDs, and track IDs
    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xywh.cpu()  # Get bounding boxes
        track_ids = results[0].boxes.id.int().cpu().tolist()  # Get track IDs
        class_ids = results[0].boxes.cls.int().cpu().tolist()  # Get class IDs
        confidences = results[0].boxes.conf.cpu().tolist()  # Get confidence scores

        # Create a copy of the frame for annotation
        annotated_frame = frame.copy()

        # Track and count unique objects
        for box, track_id, cls, conf in zip(boxes, track_ids, class_ids, confidences):
            if cls in CLASSES_TO_DETECT and conf >= CONFIDENCE_THRESHOLD:
                x, y, w, h = box

                # Only count objects appearing in the lower 2/3 of the frame
                if y + h / 2 >= FRAME_THRESHOLD_Y:
                    track = track_history[track_id]
                    track.append((float(x), float(y)))  # Store track points
                    if len(track) > 30:  # Keep the last 30 frames of history
                        track.pop(0)

                    # Ensure unique objects are only counted once
                    if track_id not in unique_objects:
                        unique_objects.add(track_id)
                        object_counts[cls] += 1  # Increment count for class

                    # Draw bounding boxes and labels for tracked classes only
                    label = f"{CLASSES_TO_DETECT[cls]} {object_counts[cls]}"
                    color = (0, 255, 0) if cls == 2 else (255, 0, 0) if cls == 1 else (0, 0, 255)
                    cv2.rectangle(annotated_frame, (int(x - w/2), int(y - h/2)), (int(x + w/2), int(y + h/2)), color, 2)
                    cv2.putText(annotated_frame, label, (int(x - w/2), int(y - h/2) - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

                    # Draw tracking lines
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=3)

        # Overlay the tally on the video
        tally_text = f"Cars: {object_counts[2]+object_counts[3]+object_counts[5]+object_counts[7]} | Bicycles: {object_counts[1]} | People: {object_counts[0]}"
        cv2.putText(annotated_frame, tally_text, (20, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        # Save the processed frame
        out.write(annotated_frame)

        # Display the frame with annotations
        cv2.imshow("YOLO Object Tracking", annotated_frame)

    frame_number += 1

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Print final count in the log
print(f"\nFinal Tally:")
print(f"Cars: {object_counts[2]}")
print(f"Bicycles: {object_counts[1]}")
print(f"People: {object_counts[0]}")
print(f"Motorcycles: {object_counts[3]}")
print(f"Buses: {object_counts[5]}")
print(f"Trucks: {object_counts[7]}")

# Release video capture and close display
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved as: {output_path}")
# Out:
# 0: 480x640 2 cars, 280.1ms
# Speed: 1.3ms preprocess, 280.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 345.2ms
# Speed: 2.5ms preprocess, 345.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 303.4ms
# Speed: 1.3ms preprocess, 303.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 311.6ms
# Speed: 1.3ms preprocess, 311.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 287.2ms
# Speed: 1.5ms preprocess, 287.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 280.9ms
# Speed: 1.1ms preprocess, 280.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 405.4ms
# Speed: 1.4ms preprocess, 405.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 513.5ms
# Speed: 1.6ms preprocess, 513.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 497.4ms
# Speed: 2.4ms preprocess, 497.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 491.3ms
# Speed: 1.6ms preprocess, 491.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 481.5ms
# Speed: 2.3ms preprocess, 481.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 448.4ms
# Speed: 1.9ms preprocess, 448.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 548.8ms
# Speed: 2.0ms preprocess, 548.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 485.1ms
# Speed: 3.0ms preprocess, 485.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 433.1ms
# Speed: 1.6ms preprocess, 433.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 456.6ms
# Speed: 2.4ms preprocess, 456.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 439.9ms
# Speed: 2.1ms preprocess, 439.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 458.2ms
# Speed: 1.9ms preprocess, 458.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 434.0ms
# Speed: 1.6ms preprocess, 434.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 429.5ms
# Speed: 1.6ms preprocess, 429.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 423.2ms
# Speed: 1.5ms preprocess, 423.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 441.9ms
# Speed: 1.7ms preprocess, 441.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 435.9ms
# Speed: 2.0ms preprocess, 435.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 435.0ms
# Speed: 1.7ms preprocess, 435.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 415.9ms
# Speed: 1.8ms preprocess, 415.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 potted plant, 483.8ms
# Speed: 1.9ms preprocess, 483.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 529.4ms
# Speed: 1.6ms preprocess, 529.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 456.1ms
# Speed: 2.0ms preprocess, 456.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 440.6ms
# Speed: 1.8ms preprocess, 440.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 425.8ms
# Speed: 1.7ms preprocess, 425.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 432.3ms
# Speed: 2.3ms preprocess, 432.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 520.7ms
# Speed: 1.6ms preprocess, 520.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 463.3ms
# Speed: 2.1ms preprocess, 463.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 motorcycle, 1 potted plant, 514.3ms
# Speed: 1.8ms preprocess, 514.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 431.5ms
# Speed: 2.1ms preprocess, 431.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 motorcycle, 1 potted plant, 456.9ms
# Speed: 2.1ms preprocess, 456.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 motorcycle, 1 potted plant, 488.1ms
# Speed: 1.8ms preprocess, 488.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 motorcycle, 1 potted plant, 451.1ms
# Speed: 1.7ms preprocess, 451.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 434.0ms
# Speed: 1.7ms preprocess, 434.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 425.0ms
# Speed: 1.6ms preprocess, 425.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 421.9ms
# Speed: 1.9ms preprocess, 421.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 452.4ms
# Speed: 1.6ms preprocess, 452.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 416.0ms
# Speed: 2.0ms preprocess, 416.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 448.9ms
# Speed: 1.7ms preprocess, 448.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 potted plant, 459.8ms
# Speed: 1.9ms preprocess, 459.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 471.2ms
# Speed: 1.8ms preprocess, 471.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 488.6ms
# Speed: 1.6ms preprocess, 488.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 416.9ms
# Speed: 2.6ms preprocess, 416.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 409.8ms
# Speed: 1.7ms preprocess, 409.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 motorcycle, 1 potted plant, 498.0ms
# Speed: 1.6ms preprocess, 498.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 531.3ms
# Speed: 2.1ms preprocess, 531.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 433.7ms
# Speed: 1.7ms preprocess, 433.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 cars, 1 potted plant, 427.9ms
# Speed: 1.8ms preprocess, 427.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 motorcycle, 1 potted plant, 453.9ms
# Speed: 2.4ms preprocess, 453.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 460.3ms
# Speed: 2.0ms preprocess, 460.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 460.4ms
# Speed: 1.9ms preprocess, 460.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 potted plant, 414.0ms
# Speed: 1.6ms preprocess, 414.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 718.5ms
# Speed: 5.6ms preprocess, 718.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 614.2ms
# Speed: 2.1ms preprocess, 614.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 potted plant, 548.2ms
# Speed: 2.2ms preprocess, 548.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 449.1ms
# Speed: 2.3ms preprocess, 449.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Final Tally:
# Cars: 4
# Bicycles: 0
# People: 0
# Motorcycles: 0
# Buses: 0
# Trucks: 0
# Processed video saved as: processed_video.mp4
